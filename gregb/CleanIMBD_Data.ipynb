# %%
import pandas as pd
import os

# %%
#import file
IMDB_movies = os.path.join("Resources/IMDb_movies.csv")

#create dataframe
IMDB_movies_df = pd.read_csv(IMDB_movies, low_memory=False)

#print data 
IMDB_movies_df.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year date_published                      genre  duration           country  \
# 0  1894     1894-10-09                    Romance        45               USA
# 1  1906     1906-12-26    Biography, Crime, Drama        70         Australia
# 2  1911     1911-08-19                      Drama        53  Germany, Denmark
# 3  1912     1912-11-13             Drama, History       100               USA
# 4  1911     1911-03-06  Adventure, Drama, Fantasy        68             Italy
#
#   language                             director  ...  \
# 0     None                      Alexander Black  ...
# 1     None                         Charles Tait  ...
# 2      NaN                            Urban Gad  ...
# 3  English                   Charles L. Gaskill  ...
# 4  Italian  Francesco Bertolini, Adolfo Padovan  ...
#
#                                               actors  \
# 0  Blanche Bayliss, William Courtenay, Chauncey D...
# 1  Elizabeth Tait, John Tait, Norman Campbell, Be...
# 2  Asta Nielsen, Valdemar Psilander, Gunnar Helse...
# 3  Helen Gardner, Pearl Sindelar, Miss Fielding, ...
# 4  Salvatore Papa, Arturo Pirovano, Giuseppe de L...
#
#                                          description avg_vote votes   budget  \
# 0  The adventures of a female reporter in the 1890s.      5.9   154      NaN
# 1  True story of notorious Australian outlaw Ned ...      6.1   589   $ 2250
# 2  Two men of high rank are both wooing the beaut...      5.8   188      NaN
# 3  The fabled queen of Egypt's affair with Roman ...      5.2   446  $ 45000
# 4  Loosely adapted from Dante's Divine Comedy and...      7.0  2237      NaN
#
#    usa_gross_income worlwide_gross_income metascore reviews_from_users  \
# 0               NaN                   NaN       NaN                1.0
# 1               NaN                   NaN       NaN                7.0
# 2               NaN                   NaN       NaN                5.0
# 3               NaN                   NaN       NaN               25.0
# 4               NaN                   NaN       NaN               31.0
#
#    reviews_from_critics
# 0                   2.0
# 1                   7.0
# 2                   2.0
# 3                   3.0
# 4                  14.0
#
# [5 rows x 22 columns]

# %%
#select needed columns
IMDB_df = IMDB_movies_df[['imdb_title_id','title','original_title','year','genre','duration','country']]
IMDB_df
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85850                         Le lion  2020                     Comedy
# 85851  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85852       Padmavyuhathile Abhimanyu  2019                      Drama
# 85853               Sokagin Çocuklari  2019              Drama, Family
# 85854      La vida sense la Sara Amat  2019                      Drama
#
#        duration           country
# 0            45               USA
# 1            70         Australia
# 2            53  Germany, Denmark
# 3           100               USA
# 4            68             Italy
# ...         ...               ...
# 85850        95   France, Belgium
# 85851       103       Netherlands
# 85852       130             India
# 85853        98            Turkey
# 85854        74             Spain
#
# [85855 rows x 7 columns]

# %%
#remove any null values 
IMDB_df1=IMDB_df.dropna()
IMDB_df1
# Out:
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85850                         Le lion  2020                     Comedy
# 85851  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85852       Padmavyuhathile Abhimanyu  2019                      Drama
# 85853               Sokagin Çocuklari  2019              Drama, Family
# 85854      La vida sense la Sara Amat  2019                      Drama
#
#        duration           country
# 0            45               USA
# 1            70         Australia
# 2            53  Germany, Denmark
# 3           100               USA
# 4            68             Italy
# ...         ...               ...
# 85850        95   France, Belgium
# 85851       103       Netherlands
# 85852       130             India
# 85853        98            Turkey
# 85854        74             Spain
#
# [85791 rows x 7 columns]

# %%
#add a new column to dataframe that combines the year and movie title and for new movie_id
IMDB_df1.insert(5,'Movie_ID','')
IMDB_df1.insert(6, 'Movie_title','')
IMDB_df1.head()
# Out:
#   imdb_title_id                        title               original_title  \
# 0     tt0000009                   Miss Jerry                   Miss Jerry
# 1     tt0000574  The Story of the Kelly Gang  The Story of the Kelly Gang
# 2     tt0001892               Den sorte drøm               Den sorte drøm
# 3     tt0002101                    Cleopatra                    Cleopatra
# 4     tt0002130                    L'Inferno                    L'Inferno
#
#    year                      genre Movie_ID Movie_title  duration  \
# 0  1894                    Romance                             45
# 1  1906    Biography, Crime, Drama                             70
# 2  1911                      Drama                             53
# 3  1912             Drama, History                            100
# 4  1911  Adventure, Drama, Fantasy                             68
#
#             country
# 0               USA
# 1         Australia
# 2  Germany, Denmark
# 3               USA
# 4             Italy

# %%
#concat year and title to create formatted movie_title
#find out what error message means
IMDB_df1['Movie_title']=IMDB_df1['year'].str.cat(IMDB_df1['title'],sep="-")
IMDB_df1
# Out:
# <ipython-input-6-bbcea301eecf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IMDB_df1['Movie_title']=IMDB_df1['year'].str.cat(IMDB_df1['title'],sep="-")
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85850                         Le lion  2020                     Comedy
# 85851  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85852       Padmavyuhathile Abhimanyu  2019                      Drama
# 85853               Sokagin Çocuklari  2019              Drama, Family
# 85854      La vida sense la Sara Amat  2019                      Drama
#
#       Movie_ID                          Movie_title  duration  \
# 0                                   1894-Miss Jerry        45
# 1                  1906-The Story of the Kelly Gang        70
# 2                               1911-Den sorte drøm        53
# 3                                    1912-Cleopatra       100
# 4                                    1911-L'Inferno        68
# ...        ...                                  ...       ...
# 85850                                  2020-Le lion        95
# 85851           2020-De Beentjes van Sint-Hildegard       103
# 85852                2019-Padmavyuhathile Abhimanyu       130
# 85853                        2019-Sokagin Çocuklari        98
# 85854               2019-La vida sense la Sara Amat        74
#
#                 country
# 0                   USA
# 1             Australia
# 2      Germany, Denmark
# 3                   USA
# 4                 Italy
# ...                 ...
# 85850   France, Belgium
# 85851       Netherlands
# 85852             India
# 85853            Turkey
# 85854             Spain
#
# [85791 rows x 9 columns]

# %%
#use hash function to generate unique movie id based on movie title
IMDB_df1['Movie_ID']=IMDB_df1['Movie_title'].apply(hash)
IMDB_df1
# Out:
# <ipython-input-7-b6de9752486e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   IMDB_df1['Movie_ID']=IMDB_df1['Movie_title'].apply(hash)
#       imdb_title_id                           title  \
# 0         tt0000009                      Miss Jerry
# 1         tt0000574     The Story of the Kelly Gang
# 2         tt0001892                  Den sorte drøm
# 3         tt0002101                       Cleopatra
# 4         tt0002130                       L'Inferno
# ...             ...                             ...
# 85850     tt9908390                         Le lion
# 85851     tt9911196  De Beentjes van Sint-Hildegard
# 85852     tt9911774       Padmavyuhathile Abhimanyu
# 85853     tt9914286               Sokagin Çocuklari
# 85854     tt9914942      La vida sense la Sara Amat
#
#                        original_title  year                      genre  \
# 0                          Miss Jerry  1894                    Romance
# 1         The Story of the Kelly Gang  1906    Biography, Crime, Drama
# 2                      Den sorte drøm  1911                      Drama
# 3                           Cleopatra  1912             Drama, History
# 4                           L'Inferno  1911  Adventure, Drama, Fantasy
# ...                               ...   ...                        ...
# 85850                         Le lion  2020                     Comedy
# 85851  De Beentjes van Sint-Hildegard  2020              Comedy, Drama
# 85852       Padmavyuhathile Abhimanyu  2019                      Drama
# 85853               Sokagin Çocuklari  2019              Drama, Family
# 85854      La vida sense la Sara Amat  2019                      Drama
#
#                   Movie_ID                          Movie_title  duration  \
# 0      2479957716636985459                      1894-Miss Jerry        45
# 1     -2306796948220175267     1906-The Story of the Kelly Gang        70
# 2     -1038286319549366125                  1911-Den sorte drøm        53
# 3      -526878952485686219                       1912-Cleopatra       100
# 4      5834265353546278254                       1911-L'Inferno        68
# ...                    ...                                  ...       ...
# 85850  4624812487133115571                         2020-Le lion        95
# 85851  -420159147134850776  2020-De Beentjes van Sint-Hildegard       103
# 85852  4196734093687209339       2019-Padmavyuhathile Abhimanyu       130
# 85853 -9011241068702941469               2019-Sokagin Çocuklari        98
# 85854 -8745703450526714457      2019-La vida sense la Sara Amat        74
#
#                 country
# 0                   USA
# 1             Australia
# 2      Germany, Denmark
# 3                   USA
# 4                 Italy
# ...                 ...
# 85850   France, Belgium
# 85851       Netherlands
# 85852             India
# 85853            Turkey
# 85854             Spain
#
# [85791 rows x 9 columns]

# %%
#export results to a csv
IMDB_df1.to_csv("Resources/Movies.csv")
